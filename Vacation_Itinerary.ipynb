# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("Vacation_Search/WeatherPy_vacation.csv")
vacation_df.head(10)
# Out:
#    City_ID         City Country  Max Temp Current Description    Lat     Lng  \
# 0        6   Butaritari      KI     81.63     overcast clouds   3.07  172.79
# 1       16   Carutapera      BR     78.13    scattered clouds  -1.20  -46.02
# 2       20      Rikitea      PF     75.96           clear sky -23.12 -134.97
# 3       28        Natal      BR     78.80          few clouds  -5.79  -35.21
# 4       30       Ixtapa      MX     84.20       broken clouds  20.70 -105.20
# 5       31         Hilo      US     86.00    scattered clouds  19.73 -155.09
# 6       42  Butterworth      MY     77.00    scattered clouds   5.40  100.36
# 7       43      Pizarro      CO     77.77          light rain   4.95  -77.37
# 8       47  San Nicolas      PH     78.80       broken clouds  18.17  120.60
# 9       50      Tautira      PF     86.00    scattered clouds -17.73 -149.15
#
#            Hotel Name
# 0  Isles Sunset Lodge
# 1          Carutapera
# 2             Rikitea
# 3               Natal
# 4     Puerto Vallarta
# 5                Hilo
# 6         George Town
# 7             Pizarro
# 8          Laoag City
# 9             Tautira

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Trip to US.
# Grab the first hotel from the results and store the name.
us_vacation_df = vacation_df.loc[(vacation_df["Country"] == "US")]
us_vacation_df.dropna()
# Out:
#      City_ID           City Country  Max Temp Current Description    Lat  \
# 5         31           Hilo      US     86.00    scattered clouds  19.73
# 12        65      Santa Ana      US     82.99       broken clouds  33.75
# 20        92          Kapaa      US     82.99     overcast clouds  22.08
# 22        94         Lompoc      US     78.01           clear sky  34.64
# 42       172    San Antonio      US     77.00           clear sky  29.42
# 53       201         Laguna      US     81.00           clear sky  38.42
# 58       212   Saint George      US     79.00           clear sky  37.10
# 68       251  San Francisco      US     77.00           clear sky  37.77
# 73       278  Discovery Bay      US     80.01           clear sky  37.91
# 78       311       Pacifica      US     75.20           clear sky  37.61
# 81       321     San Angelo      US     78.80           clear sky  31.46
# 116      419  Half Moon Bay      US     77.00           clear sky  37.46
# 134      492      San Ramon      US     81.00               smoke  37.78
# 137      503  Santa Barbara      US     87.80           clear sky  34.73
# 142      523   Hillsborough      US     77.00           clear sky  37.57
# 161      561        Kahului      US     89.60          few clouds  20.89
# 164      572       Ahuimanu      US     86.00    scattered clouds  21.44
# 182      647     Kingsville      US     80.60           clear sky  27.52
# 198      709      Brownwood      US     77.00           clear sky  31.71
#
#         Lng                Hotel Name
# 5   -155.09                      Hilo
# 12  -117.87                 Santa Ana
# 20  -159.32                    Kapaʻa
# 22  -120.46                    Lompoc
# 42   -98.49               San Antonio
# 53  -121.42                Sacramento
# 58  -113.58                St. George
# 68  -122.42             San Francisco
# 73  -121.60             Discovery Bay
# 78  -122.49                 Daly City
# 81  -100.44                San Angelo
# 116 -122.43             Half Moon Bay
# 134 -121.98                 San Ramon
# 137 -120.03  Upper Ballard Campground
# 142 -122.38                 San Mateo
# 161 -156.47                   Kahului
# 164 -157.84                  Honolulu
# 182  -97.86                Kingsville
# 198  -98.99                 Brownwood

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.
start = float(input("What is your Starting City_ID from List you would like for your trip? "))
stop1 = float(input("What is your First Stop City_ID from  List you would like for your trip? "))
stop2 = float(input("What is your Second Stop City_ID from  List you would like for your trip? "))
stop3 = float(input("What is your Thirth Stop City_ID from  List you would like for your trip? "))
end = float(input("What is your Last City_ID from MX List  would like for your trip? "))
# Out:
# What is your Starting City_ID from List you would like for your trip? 31
# What is your First Stop City_ID from  List you would like for your trip? 65
# What is your Second Stop City_ID from  List you would like for your trip? 92
# What is your Thirth Stop City_ID from  List you would like for your trip? 94
# What is your Last City_ID from MX List  would like for your trip? 172

# %%
# Start Vacation at:

vacation_start = us_vacation_df.loc[(us_vacation_df["City_ID"] == stop1)]
vacation_start = us_vacation_df.iloc[0]

vacation_stop1 = us_vacation_df.loc[(us_vacation_df["City_ID"] == stop2)]
vacation_stop1 = vacation_stop1.iloc[0]

vacation_stop2 = us_vacation_df.loc[(us_vacation_df["City_ID"] == stop3)]
vacation_stop2 = vacation_stop2.iloc[0]

vacation_stop3 = us_vacation_df.loc[(us_vacation_df["City_ID"] == end)]
vacation_stop3 = vacation_stop3.iloc[0]

vacation_end = us_vacation_df.loc[(us_vacation_df["City_ID"] <= end)]
vacation_end = vacation_end.iloc[0] 
                                     
print("Your Starting Destination is " + vacation_start["City"] + ", " + vacation_start["Country"])
print("Your Frist Stop is " + vacation_stop1["City"] + ", " + vacation_stop1["Country"])
print("Your Second Stop is " + vacation_stop2["City"] + ", " + vacation_stop2["Country"])                                     
print("Your Thirth Stop is " + vacation_stop3["City"] + ", " + vacation_stop3["Country"])                                     
print("Your Last Stop in your vacation is " + vacation_end["City"] + ", " + vacation_end["Country"])
# Out:
# Your Starting Destination is Hilo, US
# Your Frist Stop is Kapaa, US
# Your Second Stop is Lompoc, US
# Your Thirth Stop is San Antonio, US
# Your Last Stop in your vacation is Hilo, US

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start[["Lat", "Lng"]]
end = vacation_end[["Lat", "Lng"]]
stop1 = vacation_stop1[["Lat", "Lng"]]
stop2 = vacation_stop2[["Lat", "Lng"]]
stop3 = vacation_stop3[["Lat", "Lng"]]

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".

import gmaps
import gmaps.datasets
gmaps.configure(api_key=g_key)

start = (20.7, -105.2)
stop1 = (17.48, -91.43)
stop2 = (27.98, -114.06)
stop3 = (23.17, -97.95)
end = (30.85, -116.07)

fig = gmaps.figure()
sart2end_via_stops = gmaps.directions_layer(
        start, end, waypoints=[stop1, stop2, stop3],
        travel_mode='DRIVING')
fig.add_layer(sart2end_via_stops)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
#itinerary_df = pd.concat([],ignore_index=True)
#itinerary_df

us_vacation_df = pd.concat([us_vacation_df],ignore_index=True)
us_vacation_df
# Out:
#     City_ID           City Country  Max Temp Current Description    Lat  \
# 0        31           Hilo      US     86.00    scattered clouds  19.73
# 1        65      Santa Ana      US     82.99       broken clouds  33.75
# 2        92          Kapaa      US     82.99     overcast clouds  22.08
# 3        94         Lompoc      US     78.01           clear sky  34.64
# 4       172    San Antonio      US     77.00           clear sky  29.42
# 5       201         Laguna      US     81.00           clear sky  38.42
# 6       212   Saint George      US     79.00           clear sky  37.10
# 7       251  San Francisco      US     77.00           clear sky  37.77
# 8       278  Discovery Bay      US     80.01           clear sky  37.91
# 9       311       Pacifica      US     75.20           clear sky  37.61
# 10      321     San Angelo      US     78.80           clear sky  31.46
# 11      419  Half Moon Bay      US     77.00           clear sky  37.46
# 12      492      San Ramon      US     81.00               smoke  37.78
# 13      503  Santa Barbara      US     87.80           clear sky  34.73
# 14      523   Hillsborough      US     77.00           clear sky  37.57
# 15      561        Kahului      US     89.60          few clouds  20.89
# 16      572       Ahuimanu      US     86.00    scattered clouds  21.44
# 17      647     Kingsville      US     80.60           clear sky  27.52
# 18      709      Brownwood      US     77.00           clear sky  31.71
#
#        Lng                Hotel Name
# 0  -155.09                      Hilo
# 1  -117.87                 Santa Ana
# 2  -159.32                    Kapaʻa
# 3  -120.46                    Lompoc
# 4   -98.49               San Antonio
# 5  -121.42                Sacramento
# 6  -113.58                St. George
# 7  -122.42             San Francisco
# 8  -121.60             Discovery Bay
# 9  -122.49                 Daly City
# 10 -100.44                San Angelo
# 11 -122.43             Half Moon Bay
# 12 -121.98                 San Ramon
# 13 -120.03  Upper Ballard Campground
# 14 -122.38                 San Mateo
# 15 -156.47                   Kahului
# 16 -157.84                  Honolulu
# 17  -97.86                Kingsville
# 18  -98.99                 Brownwood

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
mark_info = [info_box_template.format(**row) for index, row in us_vacation_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = mexico_vacation_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
city_mark = mexico_vacation_df["City"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=mark_info)

fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
